# %% [markdown]
# # Gráficas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = [3.4 , 7.1, 16.1, 20.0, 23.1, 34.4, 40.0, 44.7, 65.9, 78.9, 96.8,115.4, 120.0]
Y = [9.59,5.29, 3.63, 3.42, 3.46, 3.06, 3.25, 3.31, 3.50, 3.86, 4.24, 4.62, 4.67 ]

for i in range(len(X)):
    x=X[i]
    y=Y[i]
    plt.plot(x,y, marker="o", color="red")

plt.plot(X,Y,color="blue",label='Datos Experimentales')

# %%
plt.plot(X,Y,label='Datos Experimentales')
plt.legend()
plt.savefig('img/datos.png')

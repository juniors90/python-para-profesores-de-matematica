# %% [markdown]
# # Limites

# %%
import string

# %%
from sympy import *

# %%
x = symbols('x')

# %%
f=(x**3-3*x**4-3*x-12)/(7*x**2+x-12)

# %%
f
# Out:
# (-3*x**4 + x**3 - 3*x - 12)/(7*x**2 + x - 12)
